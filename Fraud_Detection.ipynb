# %% [markdown]
# <a href="https://colab.research.google.com/github/isapansoni/fraud_detection/blob/master/Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-52260a9b-546c-443e-8fb4-0e65b6b80c6f" name="files[]" multiple disabled />
#      <output id="result-52260a9b-546c-443e-8fb4-0e65b6b80c6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"isapansoni","key":"eba442c4a0937cc8a4976bf639df91e9"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c ieee-fraud-detection
# Out:
# train_transaction.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_identity.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_transaction.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_identity.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip train_identity.csv.zip
# !unzip train_transaction.csv.zip
# Out:
# Archive:  train_identity.csv.zip
# replace train_identity.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Archive:  train_transaction.csv.zip
# replace train_transaction.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# ## Preprocessing Data

# %%
import pandas as pd
df_train_id = pd.read_csv('train_identity.csv')
df_train_tran = pd.read_csv('train_transaction.csv')

# %%
df_train_id.head()
# Out:
#    TransactionID  id_01  ...  DeviceType                     DeviceInfo
# 0        2987004    0.0  ...      mobile  SAMSUNG SM-G892A Build/NRD90M
# 1        2987008   -5.0  ...      mobile                     iOS Device
# 2        2987010   -5.0  ...     desktop                        Windows
# 3        2987011   -5.0  ...     desktop                            NaN
# 4        2987016    0.0  ...     desktop                          MacOS
#
# [5 rows x 41 columns]

# %%
df_train_tran.head()
# Out:
#    TransactionID  isFraud  TransactionDT  ...  V337 V338  V339
# 0        2987000        0          86400  ...   NaN  NaN   NaN
# 1        2987001        0          86401  ...   NaN  NaN   NaN
# 2        2987002        0          86469  ...   NaN  NaN   NaN
# 3        2987003        0          86499  ...   NaN  NaN   NaN
# 4        2987004        0          86506  ...   0.0  0.0   0.0
#
# [5 rows x 394 columns]

# %%
df_train_tran.shape
# Out:
# (590540, 394)

# %%
df_train_id.shape
# Out:
# (144233, 41)

# %%
df_train = pd.merge(df_train_tran, df_train_id, on='TransactionID', how='left')

# %%
print(f'Train dataset has {df_train.shape[0]} rows and {df_train.shape[1]} columns.')
# Out:
# Train dataset has 590540 rows and 434 columns.

# %%
del df_train_tran, df_train_id

# %%
df_train.head()
# Out:
#    TransactionID  isFraud  ...  DeviceType                     DeviceInfo
# 0        2987000        0  ...         NaN                            NaN
# 1        2987001        0  ...         NaN                            NaN
# 2        2987002        0  ...         NaN                            NaN
# 3        2987003        0  ...         NaN                            NaN
# 4        2987004        0  ...      mobile  SAMSUNG SM-G892A Build/NRD90M
#
# [5 rows x 434 columns]
